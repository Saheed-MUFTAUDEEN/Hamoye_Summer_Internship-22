# %% [markdown]
# ##  Stage A Quiz Solution

# %% [markdown]
# In partial fulfilment of the requirement of Hamoye Summer'22 Internship, I MUFTAUDEEN, Toyin Saheed, declares- that by submitting this document - the solution in this notebbok are results of my own work and that I abide by the code of conduct guiding the internship.

# %% [markdown]
# ## Overview: Introduction to Python for Machine Learning

# %% [markdown]
# The dataset for this quiz is provided by the Food and Agriculture Organization of the United Nations and is made available in .csv format on the github link attached herein https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning

# %% [markdown]
# ## Preliminaries

# %%
#importing the needed libraarires 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load in the dataset
food_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")

# %%
#Checking the shape of the dataset 
food_df.shape
# Out:
# (60943, 12)

# %%
#Printing the first 50 rows in the dataset
food_df.head(50)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
#Dataset description
food_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#Dataset information 
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Question 11
# What is the total sum of Animal Fat produced in 2014 and 2017??

# %%
total_sum = food_df.groupby('Item')[['Y2014', 'Y2017']].sum()
total_sum
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %% [markdown]
# ## Question 12
# What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places??

# %%
round(food_df['Y2015'].mean(), 3), round(food_df['Y2015'].std(), 3)
# Out:
# (135.236, 1603.404)

# %% [markdown]
# ## Question 13
# What is the total number and percentage of missing data in 2016 to 2 decimal places ??

# %%
round(food_df['Y2016'].isnull().sum(), 2), round(food_df['Y2016'].isnull().mean()*100, 2)
# Out:
# (1535, 2.52)

# %% [markdown]
# ## Question 14
# What year had the heighest correlation with 'Element Code' ??

# %%
food_df.groupby('Element Code').corr()
# Out:
#                         Area Code  Item Code     Y2014     Y2015     Y2016  \
# Element Code
# 511          Area Code   1.000000        NaN  0.149348  0.149792  0.150292
#              Item Code        NaN        NaN       NaN       NaN       NaN
#              Y2014       0.149348        NaN  1.000000  0.999988  0.999951
#              Y2015       0.149792        NaN  0.999988  1.000000  0.999987
#              Y2016       0.150292        NaN  0.999951  0.999987  1.000000
# ...                           ...        ...       ...       ...       ...
# 5911         Y2014       0.005901   0.056301  1.000000  0.976942  0.992694
#              Y2015       0.007883   0.050526  0.976942  1.000000  0.965195
#              Y2016       0.006203   0.062306  0.992694  0.965195  1.000000
#              Y2017       0.005156   0.063080  0.941934  0.863665  0.963790
#              Y2018       0.004272   0.063211  0.942024  0.863140  0.963378
#
#                            Y2017     Y2018
# ...

# %% [markdown]
# ## Question 15
# What year has the heighest sum of import Quantity ??
# ## Question 16
# What is the total number of the sum of Production in 2014 ??

# %%
food_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ## Question 17
# Which elements had the highest sum in 2018 ??
#
# ## Question 18
# Which elements had the 3rd lowest sum in 2018 ??

# %%
food_df.groupby('Element')[['Y2018']].sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# ## Question 19
# what is the total import Quantity in Algeria in 2018 ??

# %%
food_df[food_df['Area']=='Algeria'].sum()
# Out:
# Area Code                                                    5252
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 3532053
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                              5017927
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                   313375.33
# Y2015                                                    324058.4
# Y2016                                                   326007.41
# Y2017                                                   325644.27
# Y2018                                                   341729.98
# dtype: object

# %% [markdown]
# ## Question 20
# What is the total number of unique countries in the dataset

# %%
food_df['Area'].nunique()
# Out:
# 49
