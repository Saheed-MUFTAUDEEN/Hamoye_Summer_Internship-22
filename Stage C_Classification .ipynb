# %%
#importing the neccessary libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier 
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold, LeaveOneOut
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix

# %%
#Import Dataset
grid_stability =  pd.read_csv('Data_for_UCI_named.csv')

# %%
#print the dataframe 
grid_stability
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4      stab     stabf
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  0.023892  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120 -0.025803    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984 -0.031810    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  0.037789  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  0.045263  unstable
#
# [10000 rows x 14 columns]

# %%
#Getting the dataset information;columns and datatypes.
grid_stability.dtypes
# Out:
# tau1     float64
# tau2     float64
# tau3     float64
# tau4     float64
# p1       float64
# p2       float64
# p3       float64
# p4       float64
# g1       float64
# g2       float64
# g3       float64
# g4       float64
# stab     float64
# stabf     object
# dtype: object

# %%
#Checking for missing data 
grid_stability.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
# Because of the direct relationship between stab and stabf, stab is drop and stabf will remains the sole target variabe 
grid_stability.drop('stab', axis =1, inplace = True)
grid_stability.T
# Out:
#            0         1         2         3         4         5         6     \
# tau1    2.95906  9.304097  8.971707  0.716415  3.134112  6.999209  6.710166
# tau2   3.079885  4.902524  8.848428    7.6696  7.608772  9.109247  3.765204
# tau3   8.381025  3.047541  3.046479  4.486641  4.943759  3.784066  6.929314
# tau4   9.780754  1.369357  1.214518  2.340563  9.857573  4.267788  8.818562
# p1     3.763085  5.067812  3.405158  3.963791  3.525811  4.429669  2.397419
# p2    -0.782604 -1.940058 -1.207456 -1.027473 -1.125531 -1.857139  -0.61459
# p3    -1.257395 -1.872742  -1.27721 -1.938944 -1.845975 -0.670397 -1.208826
# p4    -1.723086 -1.255012 -0.920492 -0.997374 -0.554305 -1.902133 -0.574004
# g1     0.650456  0.413441  0.163041  0.446209   0.79711  0.261793   0.17789
# g2     0.859578  0.862414  0.766689  0.976744   0.45545   0.07793  0.397977
# g3     0.887445  0.562139  0.839444  0.929381  0.656947  0.542884  0.402046
# g4     0.958034   0.78176  0.109853  0.362718  0.820923  0.469931   0.37663
# stabf  unstable    stable  unstable  unstable  unstable    stable  unstable
#
#            7         8         9     ...      9990      9991      9992  \
# tau1   6.953512  4.689852  9.841496  ...  5.783299  0.998988  3.114442
# tau2   1.379125  4.007747  1.413822  ...  4.726614  9.924916  4.781072
# tau3     5.7194  1.478573  9.769856  ...  1.340273  8.926563  2.427918
# tau4   7.870307  3.733787  7.641616  ...  8.617933  2.885941  7.989509
# p1     3.224495    4.0413  4.727595  ...  4.587533  3.660232  2.673156
# p2    -0.748998 -1.410344 -1.991363  ... -1.950574 -1.103521 -0.918191
# p3    -1.186517 -1.238204 -0.857637  ... -1.594137 -1.105641 -0.652736
# p4     -1.28898 -1.392751 -1.878594  ... -1.042822  -1.45107 -1.102228
# g1     0.371385  0.269708  0.376356  ...  0.445853   0.71766   0.86795
# g2     0.633204  0.250364  0.544415  ...   0.64568  0.954919  0.888858
# g3     0.732741  0.164941  0.792039  ...  0.406864  0.491107  0.460587
# g4     0.380544  0.482439  0.116263  ...   0.72618  0.692023  0.965026
# stabf  unstable    stable  unstable  ...  unstable  unstable  unstable
#
#            9993      9994      9995      9996      9997      9998      9999
# tau1   5.754191  2.042954  2.930406  3.392299  2.364034  9.631511  6.530527
# tau2   3.032743  8.514335  9.487627  1.274827   2.84203  3.994398   6.78179
# tau3   5.084803  8.173809  2.376523  2.954947  8.776391  2.757071  4.349695
# tau4   4.633624  5.466635  6.187797  6.894759  1.008906  7.821347  8.673138
# p1      5.19925  3.783797  3.343416  4.349512  4.299976  2.514755  3.492807
# p2     -1.71703 -1.639912 -0.658054 -1.663661 -1.380719  -0.96633 -1.390285
# p3    -1.713212 -0.662469 -1.449106 -0.952437 -0.943884 -0.649915 -1.532193
# p4    -1.769009 -1.481417 -1.236256 -1.733414 -1.975373  -0.89851 -0.570329
# g1     0.157284  0.154129  0.601709  0.502079  0.487838  0.365246  0.073056
# g2     0.975921  0.944486  0.779642  0.567242  0.986505  0.587558  0.505441
# g3     0.511555  0.053225  0.813512   0.28588  0.149286  0.889118  0.378761
# g4     0.696591  0.499109  0.608385   0.36612  0.145984  0.818391  0.942631
# stabf  unstable  unstable  unstable    stable    stable  unstable  unstable
#
# [13 rows x 10000 columns]

# %%
#Get the count of items in the target variable column 
grid_stability.stabf.value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
#Converting the target variable datatype 
grid_stability['stabf'] = (grid_stability.stabf == "unstable").astype(int)

# %%
grid_stability.T
# Out:
#            0         1         2         3         4         5         6     \
# tau1   2.959060  9.304097  8.971707  0.716415  3.134112  6.999209  6.710166
# tau2   3.079885  4.902524  8.848428  7.669600  7.608772  9.109247  3.765204
# tau3   8.381025  3.047541  3.046479  4.486641  4.943759  3.784066  6.929314
# tau4   9.780754  1.369357  1.214518  2.340563  9.857573  4.267788  8.818562
# p1     3.763085  5.067812  3.405158  3.963791  3.525811  4.429669  2.397419
# p2    -0.782604 -1.940058 -1.207456 -1.027473 -1.125531 -1.857139 -0.614590
# p3    -1.257395 -1.872742 -1.277210 -1.938944 -1.845975 -0.670397 -1.208826
# p4    -1.723086 -1.255012 -0.920492 -0.997374 -0.554305 -1.902133 -0.574004
# g1     0.650456  0.413441  0.163041  0.446209  0.797110  0.261793  0.177890
# g2     0.859578  0.862414  0.766689  0.976744  0.455450  0.077930  0.397977
# g3     0.887445  0.562139  0.839444  0.929381  0.656947  0.542884  0.402046
# g4     0.958034  0.781760  0.109853  0.362718  0.820923  0.469931  0.376630
# stabf  1.000000  0.000000  1.000000  1.000000  1.000000  0.000000  1.000000
#
#            7         8         9     ...      9990      9991      9992  \
# tau1   6.953512  4.689852  9.841496  ...  5.783299  0.998988  3.114442
# tau2   1.379125  4.007747  1.413822  ...  4.726614  9.924916  4.781072
# tau3   5.719400  1.478573  9.769856  ...  1.340273  8.926563  2.427918
# tau4   7.870307  3.733787  7.641616  ...  8.617933  2.885941  7.989509
# p1     3.224495  4.041300  4.727595  ...  4.587533  3.660232  2.673156
# p2    -0.748998 -1.410344 -1.991363  ... -1.950574 -1.103521 -0.918191
# p3    -1.186517 -1.238204 -0.857637  ... -1.594137 -1.105641 -0.652736
# p4    -1.288980 -1.392751 -1.878594  ... -1.042822 -1.451070 -1.102228
# g1     0.371385  0.269708  0.376356  ...  0.445853  0.717660  0.867950
# g2     0.633204  0.250364  0.544415  ...  0.645680  0.954919  0.888858
# g3     0.732741  0.164941  0.792039  ...  0.406864  0.491107  0.460587
# g4     0.380544  0.482439  0.116263  ...  0.726180  0.692023  0.965026
# stabf  1.000000  0.000000  1.000000  ...  1.000000  1.000000  1.000000
#
#            9993      9994      9995      9996      9997      9998      9999
# tau1   5.754191  2.042954  2.930406  3.392299  2.364034  9.631511  6.530527
# tau2   3.032743  8.514335  9.487627  1.274827  2.842030  3.994398  6.781790
# tau3   5.084803  8.173809  2.376523  2.954947  8.776391  2.757071  4.349695
# tau4   4.633624  5.466635  6.187797  6.894759  1.008906  7.821347  8.673138
# p1     5.199250  3.783797  3.343416  4.349512  4.299976  2.514755  3.492807
# p2    -1.717030 -1.639912 -0.658054 -1.663661 -1.380719 -0.966330 -1.390285
# p3    -1.713212 -0.662469 -1.449106 -0.952437 -0.943884 -0.649915 -1.532193
# p4    -1.769009 -1.481417 -1.236256 -1.733414 -1.975373 -0.898510 -0.570329
# g1     0.157284  0.154129  0.601709  0.502079  0.487838  0.365246  0.073056
# g2     0.975921  0.944486  0.779642  0.567242  0.986505  0.587558  0.505441
# g3     0.511555  0.053225  0.813512  0.285880  0.149286  0.889118  0.378761
# g4     0.696591  0.499109  0.608385  0.366120  0.145984  0.818391  0.942631
# stabf  1.000000  1.000000  1.000000  0.000000  0.000000  1.000000  1.000000
#
# [13 rows x 10000 columns]

# %%
# Encode the categorical data(traget variable) into numerical
encoder = OneHotEncoder(sparse = False)

stabf_encode = encoder.fit_transform(grid_stability[['stabf']])

# %%
grid_stability.T
# Out:
#            0         1         2         3         4         5         6     \
# tau1   2.959060  9.304097  8.971707  0.716415  3.134112  6.999209  6.710166
# tau2   3.079885  4.902524  8.848428  7.669600  7.608772  9.109247  3.765204
# tau3   8.381025  3.047541  3.046479  4.486641  4.943759  3.784066  6.929314
# tau4   9.780754  1.369357  1.214518  2.340563  9.857573  4.267788  8.818562
# p1     3.763085  5.067812  3.405158  3.963791  3.525811  4.429669  2.397419
# p2    -0.782604 -1.940058 -1.207456 -1.027473 -1.125531 -1.857139 -0.614590
# p3    -1.257395 -1.872742 -1.277210 -1.938944 -1.845975 -0.670397 -1.208826
# p4    -1.723086 -1.255012 -0.920492 -0.997374 -0.554305 -1.902133 -0.574004
# g1     0.650456  0.413441  0.163041  0.446209  0.797110  0.261793  0.177890
# g2     0.859578  0.862414  0.766689  0.976744  0.455450  0.077930  0.397977
# g3     0.887445  0.562139  0.839444  0.929381  0.656947  0.542884  0.402046
# g4     0.958034  0.781760  0.109853  0.362718  0.820923  0.469931  0.376630
# stabf  1.000000  0.000000  1.000000  1.000000  1.000000  0.000000  1.000000
#
#            7         8         9     ...      9990      9991      9992  \
# tau1   6.953512  4.689852  9.841496  ...  5.783299  0.998988  3.114442
# tau2   1.379125  4.007747  1.413822  ...  4.726614  9.924916  4.781072
# tau3   5.719400  1.478573  9.769856  ...  1.340273  8.926563  2.427918
# tau4   7.870307  3.733787  7.641616  ...  8.617933  2.885941  7.989509
# p1     3.224495  4.041300  4.727595  ...  4.587533  3.660232  2.673156
# p2    -0.748998 -1.410344 -1.991363  ... -1.950574 -1.103521 -0.918191
# p3    -1.186517 -1.238204 -0.857637  ... -1.594137 -1.105641 -0.652736
# p4    -1.288980 -1.392751 -1.878594  ... -1.042822 -1.451070 -1.102228
# g1     0.371385  0.269708  0.376356  ...  0.445853  0.717660  0.867950
# g2     0.633204  0.250364  0.544415  ...  0.645680  0.954919  0.888858
# g3     0.732741  0.164941  0.792039  ...  0.406864  0.491107  0.460587
# g4     0.380544  0.482439  0.116263  ...  0.726180  0.692023  0.965026
# stabf  1.000000  0.000000  1.000000  ...  1.000000  1.000000  1.000000
#
#            9993      9994      9995      9996      9997      9998      9999
# tau1   5.754191  2.042954  2.930406  3.392299  2.364034  9.631511  6.530527
# tau2   3.032743  8.514335  9.487627  1.274827  2.842030  3.994398  6.781790
# tau3   5.084803  8.173809  2.376523  2.954947  8.776391  2.757071  4.349695
# tau4   4.633624  5.466635  6.187797  6.894759  1.008906  7.821347  8.673138
# p1     5.199250  3.783797  3.343416  4.349512  4.299976  2.514755  3.492807
# p2    -1.717030 -1.639912 -0.658054 -1.663661 -1.380719 -0.966330 -1.390285
# p3    -1.713212 -0.662469 -1.449106 -0.952437 -0.943884 -0.649915 -1.532193
# p4    -1.769009 -1.481417 -1.236256 -1.733414 -1.975373 -0.898510 -0.570329
# g1     0.157284  0.154129  0.601709  0.502079  0.487838  0.365246  0.073056
# g2     0.975921  0.944486  0.779642  0.567242  0.986505  0.587558  0.505441
# g3     0.511555  0.053225  0.813512  0.285880  0.149286  0.889118  0.378761
# g4     0.696591  0.499109  0.608385  0.366120  0.145984  0.818391  0.942631
# stabf  1.000000  1.000000  1.000000  0.000000  0.000000  1.000000  1.000000
#
# [13 rows x 10000 columns]

# %%
x = grid_stability.drop(columns='stabf')
y = grid_stability['stabf']

# split the data into training and testing sets 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
y_train.value_counts()
# Out:
# 1    5092
# 0    2908
# Name: stabf, dtype: int64

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\l-admin\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\l-admin\anaconda3\lib\site-packages (from imbalanced-learn) (1.6.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\l-admin\anaconda3\lib\site-packages (from imbalanced-learn) (1.1.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\l-admin\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\l-admin\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\l-admin\anaconda3\lib\site-packages (from imbalanced-learn) (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#There is imbalance in the observe data set

from imblearn.over_sampling import SMOTE 
smote = SMOTE(random_state = 1)
x_train_bal, y_train_bal = smote.fit_resample(x_train, y_train)

# %%
x_train_bal.value_counts()
# Out:
# tau1      tau2      tau3      tau4      p1        p2         p3         p4         g1        g2        g3        g4
# 0.500793  6.734360  5.284357  5.797771  3.387591  -0.752656  -0.972783  -1.662152  0.802707  0.204237  0.642260  0.513210    1
# 6.630654  9.745850  2.419101  2.736891  3.686849  -1.787698  -1.214773  -0.684378  0.118274  0.229779  0.604040  0.452518    1
# 6.623862  6.841372  4.216249  1.816077  4.581995  -1.812553  -1.388942  -1.380500  0.374776  0.127695  0.832619  0.391101    1
# 6.625460  8.851015  9.413108  9.330661  3.886869  -1.036351  -1.104742  -1.745777  0.378542  0.510910  0.843751  0.336192    1
# 6.627050  3.537235  5.915826  1.702248  2.702847  -0.612258  -0.634343  -1.456247  0.199006  0.643758  0.431489  0.214037    1
#                                                                                                                             ..
# 3.300592  5.745264  3.595685  3.178341  3.104557  -0.581319  -0.732578  -1.790660  0.295935  0.505183  0.536511  0.515749    1
# 3.300930  7.802465  0.720843  5.917367  4.675899  -1.166293  -1.772584  -1.737022  0.750809  0.386011  0.478856  0.201817    1
# 3.302390  9.839883  1.882652  4.875375  4.714462  -1.924809  -1.883492  -0.906162  0.093198  0.942156  0.225119  0.231710    1
# 3.302696  0.610290  1.696949  9.166912  3.442676  -1.440834  -0.703071  -1.298771  0.625756  0.967438  0.540252  0.526103    1
# 9.999469  5.677620  8.002448  7.360514  3.280473  -0.870700  -0.707238  -1.702536  0.584174  0.296674  0.710548  0.233335    1
# Length: 10184, dtype: int64

# %%
y_train_bal.value_counts()
# Out:
# 0    5092
# 1    5092
# Name: stabf, dtype: int64

# %%
#normalize the datasets using standard scaler 
scaler = StandardScaler()
normalised_train_df = scaler.fit_transform(x_train_bal)
normalised_train_df = pd.DataFrame(normalised_train_df, columns= x_train_bal.columns)

x_test = x_test.reset_index(drop=True)
normalised_test_df = scaler.transform(x_test)
normalised_test_df = pd.DataFrame(normalised_test_df, columns = x_test.columns)

# %% [markdown]
# ## Random Forest Classification Model

# %%
#Classification With RandomForest
rmdf = RandomForestClassifier()
rmdf.fit(normalised_train_df, y_train_bal)

y_preds = rmdf.predict(normalised_test_df)

# %%
rmdf = RandomForestClassifier()
scores = cross_val_score(rmdf, normalised_train_df, y_train_bal, cv=5, scoring = 'f1_macro')
print(scores)
print(scores.mean())
# Out:
# [0.92095847 0.925379   0.92390587 0.95772676 0.95424616]
# 0.9364432532504982

# %%
loo = LeaveOneOut()
scores = cross_val_score(RandomForestClassifier(), normalised_train_df, y_train_bal, cv=loo, scoring = 'f1_macro')
scores.mean()

# %%
def metric_evaluation (model_name, y_true, y_pred):
    f1_val = f1_score(y_true, y_pred)
    print(f'F1 score for {model_name} on cross_validation: {f1_val}')
    
    Accuracy = accuracy_score(y_true, y_pred)
    print(f'Accuracy score for {model_name} on cross_validation: {Accuracy}')
    
    Precision = precision_score(y_true, y_pred)
    print(f'Precision score for {model_name} on cross_validation: {Precision}')
    
    Recall = recall_score(y_true, y_pred)
    print(f'Recall score for {model_name} on cross_validation: {Recall}')

# %%
metric_evaluation(model_name = "RandomForestClassifier", y_true = y_test, y_pred = y_preds)
# Out:
# F1 score for RandomForestClassifier on cross_validation: 0.9330708661417323
# Accuracy score for RandomForestClassifier on cross_validation: 0.915
# Precision score for RandomForestClassifier on cross_validation: 0.9464856230031949
# Recall score for RandomForestClassifier on cross_validation: 0.9200310559006211

# %% [markdown]
# ## Extra Trees Classification

# %%
etc = ExtraTreesClassifier()
scores = cross_val_score(etc, normalised_train_df, y_train_bal, cv=5, scoring = 'f1_macro')
print(scores)
print(scores.mean())
# Out:
# [0.92586788 0.94746564 0.94206552 0.95870388 0.96557817]
# 0.947936217897319

# %%
etc = ExtraTreesClassifier()
etc.fit(normalised_train_df, y_train_bal)

y_preds = etc.predict(normalised_test_df)

# %%
def metric_evaluation (model_name, y_true, y_pred):
    f1_val = f1_score(y_true, y_pred)
    print(f'F1 score for {model_name} on cross_validation: {f1_val}')
    
    Accuracy = accuracy_score(y_true, y_pred)
    print(f'Accuracy score for {model_name} on cross_validation: {Accuracy}')
    
    Precision = precision_score(y_true, y_pred)
    print(f'Precision score for {model_name} on cross_validation: {Precision}')
    
    Recall = recall_score(y_true, y_pred)
    print(f'Recall score for {model_name} on cross_validation: {Recall}')

# %%
metric_evaluation(model_name = "Extra Trees Classifier", y_true = y_test, y_pred = y_preds)
# Out:
# F1 score for Extra Trees Classifier on cross_validation: 0.9382044306257287
# Accuracy score for Extra Trees Classifier on cross_validation: 0.9205
# Precision score for Extra Trees Classifier on cross_validation: 0.9392996108949416
# Recall score for Extra Trees Classifier on cross_validation: 0.937111801242236

# %% [markdown]
# ## XGboost Classifier

# %%
xgboost = XGBClassifier()
scores = cross_val_score(xgboost, normalised_train_df, y_train_bal, cv=5, scoring = 'f1_macro')
print(scores)
print(scores.mean())
# Out:
# [0.94354356 0.95532491 0.95139743 0.97494809 0.97296929]
# 0.9596366542500181

# %%
xgboost = XGBClassifier()
xgboost.fit(normalised_train_df, y_train_bal)

y_preds = xgboost.predict(normalised_test_df)

# %%
def metric_evaluation (model_name, y_true, y_pred):
    f1_val = f1_score(y_true, y_pred)
    print(f'F1 score for {model_name} on cross_validation: {f1_val}')
    
    Accuracy = accuracy_score(y_true, y_pred)
    print(f'Accuracy score for {model_name} on cross_validation: {Accuracy}')
    
    Precision = precision_score(y_true, y_pred)
    print(f'Precision score for {model_name} on cross_validation: {Precision}')
    
    Recall = recall_score(y_true, y_pred)
    print(f'Recall score for {model_name} on cross_validation: {Recall}')

# %%
metric_evaluation(model_name = "XGBClassifier", y_true = y_test, y_pred = y_preds)
# Out:
# F1 score for XGBClassifier on cross_validation: 0.954099646920361
# Accuracy score for XGBClassifier on cross_validation: 0.9415
# Precision score for XGBClassifier on cross_validation: 0.964314036478985
# Recall score for XGBClassifier on cross_validation: 0.9440993788819876

# %% [markdown]
# ## Light GBM

# %%
lgbtm = LGBMClassifier()
scores = cross_val_score(lgbtm, normalised_train_df, y_train_bal, cv=5, scoring = 'f1_macro')
print(scores)
print(scores.mean())
# Out:
# [0.94010787 0.94550174 0.94205457 0.97151159 0.96854685]
# 0.9535445234288987

# %%
lgbtm = LGBMClassifier()
lgbtm.fit(normalised_train_df, y_train_bal)

y_preds = lgbtm.predict(normalised_test_df)

# %%
def metric_evaluation (model_name, y_true, y_pred):
    f1_val = f1_score(y_true, y_pred)
    print(f'F1 score for {model_name} on cross_validation: {f1_val}')
    
    Accuracy = accuracy_score(y_true, y_pred)
    print(f'Accuracy score for {model_name} on cross_validation: {Accuracy}')
    
    Precision = precision_score(y_true, y_pred)
    print(f'Precision score for {model_name} on cross_validation: {Precision}')
    
    Recall = recall_score(y_true, y_pred)
    print(f'Recall score for {model_name} on cross_validation: {Recall}')

# %%
metric_evaluation(model_name = "LGBMClassifier", y_true = y_test, y_pred = y_preds)
# Out:
# F1 score for LGBMClassifier on cross_validation: 0.9488993710691823
# Accuracy score for LGBMClassifier on cross_validation: 0.935
# Precision score for LGBMClassifier on cross_validation: 0.9609872611464968
# Recall score for LGBMClassifier on cross_validation: 0.937111801242236
